# %% [markdown]
# <a href="https://colab.research.google.com/github/DevBatra05/AIML_Sem_4/blob/main/Lab_06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_iris
from sklearn.cluster import KMeans, DBSCAN
from sklearn.decomposition import PCA
iris = load_iris()
X = iris.data

# %%
#Reduce data to 2D for plotting
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

# %%
# Apply KMeans
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans_labels = kmeans.fit_predict(X)

# %%
#Apply DBSCAN
dbscan = DBSCAN(eps=0.5, min_samples=5)
dbscan_labels = dbscan.fit_predict(X)

# %%
#Visualize clusters
import matplotlib.pyplot as plt
plt.figure(figsize=(12,5))

# %%
#Plot KMeans
plt.subplot(1,2,1)
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=kmeans_labels, cmap='viridis')
plt.title("K-Means Clustering")
# Out:
# Text(0.5, 1.0, 'K-Means Clustering')

# %%
# Plot DBSCAN
plt.subplot(1,2,2)
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=dbscan_labels, cmap='plasma')
plt.title("DBSCAN Clustering")
# Out:
# Text(0.5, 1.0, 'DBSCAN Clustering')
